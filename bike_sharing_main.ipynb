# %% [markdown]
# <a href="https://colab.research.google.com/github/adilbm009/Seoul-Bike-Sharing-Demand-Prediction/blob/main/bike_sharing_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <b><u> Project Title : Seoul Bike Sharing Demand Prediction </u></b>

# %% [markdown]
# ## <b> Problem Description </b>
#
# ### Currently Rental bikes are introduced in many urban cities for the enhancement of mobility comfort. It is important to make the rental bike available and accessible to the public at the right time as it lessens the waiting time. Eventually, providing the city with a stable supply of rental bikes becomes a major concern. The crucial part is the prediction of bike count required at each hour for the stable supply of rental bikes.

# %% [markdown]
# ## <b> Data Description </b>
#
# ### <b> The dataset contains weather information (Temperature, Humidity, Windspeed, Visibility, Dewpoint, Solar radiation, Snowfall, Rainfall), the number of bikes rented per hour and date information.</b>
#
#
# ### <b>Attribute Information: </b>
#
# * ### Date : year-month-day
# * ### Rented Bike count - Count of bikes rented at each hour
# * ### Hour - Hour of he day
# * ### Temperature-Temperature in Celsius
# * ### Humidity - %
# * ### Windspeed - m/s
# * ### Visibility - 10m
# * ### Dew point temperature - Celsius
# * ### Solar radiation - MJ/m2
# * ### Rainfall - mm
# * ### Snowfall - cm
# * ### Seasons - Winter, Spring, Summer, Autumn
# * ### Holiday - Holiday/No holiday
# * ### Functional Day - NoFunc(Non Functional Hours), Fun(Functional hours)

# %%
# IMPORTING LIBRARIES 
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/ALMABETTER/ML 1st proj/SeoulBikeData.csv"

# %%
# READING DATASET
df = pd.read_csv(path, encoding= 'unicode_escape')

# %% [markdown]
# DATA CLEANING

# %%
df.head(50)
# Out:
#           Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0   01/12/2017                254     0             -5.2           37
# 1   01/12/2017                204     1             -5.5           38
# 2   01/12/2017                173     2             -6.0           39
# 3   01/12/2017                107     3             -6.2           40
# 4   01/12/2017                 78     4             -6.0           36
# 5   01/12/2017                100     5             -6.4           37
# 6   01/12/2017                181     6             -6.6           35
# 7   01/12/2017                460     7             -7.4           38
# 8   01/12/2017                930     8             -7.6           37
# 9   01/12/2017                490     9             -6.5           27
# 10  01/12/2017                339    10             -3.5           24
# 11  01/12/2017                360    11             -0.5           21
# 12  01/12/2017                449    12              1.7           23
# 13  01/12/2017                451    13              2.4           25
# 14  01/12/2017                447    14              3.0           26
# 15  01/12/2017                463    15              2.1           36
# 16  01/12/2017                484    16              1.2           54
# 17  01/12/2017                555    17              0.8           58
# 18  01/12/2017                862    18              0.6           66
# 19  01/12/2017                600    19              0.0           77
# 20  01/12/2017                426    20             -0.3           79
# 21  01/12/2017                405    21             -0.8           81
# 22  01/12/2017                398    22             -0.9           83
# 23  01/12/2017                323    23             -1.3           84
# 24  02/12/2017                328     0             -1.8           87
# 25  02/12/2017                308     1             -2.2           86
# 26  02/12/2017                262     2             -2.9           86
# 27  02/12/2017                167     3             -3.5           81
# 28  02/12/2017                 89     4             -3.8           79
# 29  02/12/2017                 79     5             -4.0           79
# 30  02/12/2017                 70     6             -4.3           82
# 31  02/12/2017                146     7             -4.4           81
# 32  02/12/2017                219     8             -4.2           79
# 33  02/12/2017                328     9             -2.9           68
# 34  02/12/2017                334    10             -0.4           57
# 35  02/12/2017                388    11              1.9           49
# 36  02/12/2017                479    12              4.3           41
# 37  02/12/2017                606    13              6.0           36
# 38  02/12/2017                611    14              7.3           35
# 39  02/12/2017                589    15              7.6           41
# 40  02/12/2017                618    16              6.4           48
# 41  02/12/2017                572    17              6.0           51
# 42  02/12/2017                489    18              5.5           53
# 43  02/12/2017                385    19              5.0           52
# 44  02/12/2017                359    20              4.6           51
# 45  02/12/2017                377    21              4.1           55
# 46  02/12/2017                354    22              3.5           54
# 47  02/12/2017                366    23              4.0           56
# 48  03/12/2017                342     0              4.0           58
# 49  03/12/2017                227     1              3.9           69
#
#     Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0                2.2              2000                      -17.6
# 1                0.8              2000                      -17.6
# 2                1.0              2000                      -17.7
# 3                0.9              2000                      -17.6
# 4                2.3              2000                      -18.6
# 5                1.5              2000                      -18.7
# 6                1.3              2000                      -19.5
# 7                0.9              2000                      -19.3
# 8                1.1              2000                      -19.8
# 9                0.5              1928                      -22.4
# 10               1.2              1996                      -21.2
# 11               1.3              1936                      -20.2
# 12               1.4              2000                      -17.2
# 13               1.6              2000                      -15.6
# 14               2.0              2000                      -14.6
# 15               3.2              2000                      -11.4
# 16               4.2               793                       -7.0
# 17               1.6              2000                       -6.5
# 18               1.4              2000                       -5.0
# 19               1.7              2000                       -3.5
# 20               1.5              1913                       -3.5
# 21               0.8              1687                       -3.6
# 22               1.5              1380                       -3.4
# 23               1.0              1265                       -3.6
# 24               1.1               994                       -3.6
# 25               0.6               990                       -4.2
# 26               1.5              1256                       -4.9
# 27               2.2              1221                       -6.2
# 28               2.0              1167                       -6.9
# 29               1.5              1202                       -7.1
# 30               2.1              1178                       -6.9
# 31               2.5              1276                       -7.1
# 32               2.1              1436                       -7.3
# 33               1.6              1487                       -7.9
# 34               1.6              1309                       -7.8
# 35               1.8              1406                       -7.7
# 36               1.3              1666                       -7.8
# 37               1.8              1780                       -7.9
# 38               1.3              1955                       -7.1
# 39               2.3              1953                       -4.8
# 40               2.6              1945                       -3.8
# 41               2.5              1891                       -3.3
# 42               1.5              1697                       -3.3
# 43               2.3              1666                       -4.0
# 44               1.2              1585                       -4.6
# 45               1.2              1448                       -4.1
# 46               1.5              1446                       -4.9
# 47               1.0              1352                       -4.0
# 48               1.4              1296                       -3.5
# 49               1.7               485                       -1.2
#
#     Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.00           0.0            0.0  Winter  No Holiday
# 1                      0.00           0.0            0.0  Winter  No Holiday
# 2                      0.00           0.0            0.0  Winter  No Holiday
# 3                      0.00           0.0            0.0  Winter  No Holiday
# 4                      0.00           0.0            0.0  Winter  No Holiday
# 5                      0.00           0.0            0.0  Winter  No Holiday
# 6                      0.00           0.0            0.0  Winter  No Holiday
# 7                      0.00           0.0            0.0  Winter  No Holiday
# 8                      0.01           0.0            0.0  Winter  No Holiday
# 9                      0.23           0.0            0.0  Winter  No Holiday
# 10                     0.65           0.0            0.0  Winter  No Holiday
# 11                     0.94           0.0            0.0  Winter  No Holiday
# 12                     1.11           0.0            0.0  Winter  No Holiday
# 13                     1.16           0.0            0.0  Winter  No Holiday
# 14                     1.01           0.0            0.0  Winter  No Holiday
# 15                     0.54           0.0            0.0  Winter  No Holiday
# 16                     0.24           0.0            0.0  Winter  No Holiday
# 17                     0.08           0.0            0.0  Winter  No Holiday
# 18                     0.00           0.0            0.0  Winter  No Holiday
# 19                     0.00           0.0            0.0  Winter  No Holiday
# 20                     0.00           0.0            0.0  Winter  No Holiday
# 21                     0.00           0.0            0.0  Winter  No Holiday
# 22                     0.00           0.0            0.0  Winter  No Holiday
# 23                     0.00           0.0            0.0  Winter  No Holiday
# 24                     0.00           0.0            0.0  Winter  No Holiday
# 25                     0.00           0.0            0.0  Winter  No Holiday
# 26                     0.00           0.0            0.0  Winter  No Holiday
# 27                     0.00           0.0            0.0  Winter  No Holiday
# 28                     0.00           0.0            0.0  Winter  No Holiday
# 29                     0.00           0.0            0.0  Winter  No Holiday
# 30                     0.00           0.0            0.0  Winter  No Holiday
# 31                     0.00           0.0            0.0  Winter  No Holiday
# 32                     0.01           0.0            0.0  Winter  No Holiday
# 33                     0.30           0.0            0.0  Winter  No Holiday
# 34                     0.80           0.0            0.0  Winter  No Holiday
# 35                     1.00           0.0            0.0  Winter  No Holiday
# 36                     1.09           0.0            0.0  Winter  No Holiday
# 37                     1.12           0.0            0.0  Winter  No Holiday
# 38                     0.99           0.0            0.0  Winter  No Holiday
# 39                     0.74           0.0            0.0  Winter  No Holiday
# 40                     0.22           0.0            0.0  Winter  No Holiday
# 41                     0.06           0.0            0.0  Winter  No Holiday
# 42                     0.00           0.0            0.0  Winter  No Holiday
# 43                     0.00           0.0            0.0  Winter  No Holiday
# 44                     0.00           0.0            0.0  Winter  No Holiday
# 45                     0.00           0.0            0.0  Winter  No Holiday
# 46                     0.00           0.0            0.0  Winter  No Holiday
# 47                     0.00           0.0            0.0  Winter  No Holiday
# 48                     0.00           0.0            0.0  Winter  No Holiday
# 49                     0.00           0.0            0.0  Winter  No Holiday
#
#    Functioning Day
# 0              Yes
# 1              Yes
# 2              Yes
# 3              Yes
# 4              Yes
# 5              Yes
# 6              Yes
# 7              Yes
# 8              Yes
# 9              Yes
# 10             Yes
# 11             Yes
# 12             Yes
# 13             Yes
# 14             Yes
# 15             Yes
# 16             Yes
# 17             Yes
# 18             Yes
# 19             Yes
# 20             Yes
# 21             Yes
# 22             Yes
# 23             Yes
# 24             Yes
# 25             Yes
# 26             Yes
# 27             Yes
# 28             Yes
# 29             Yes
# 30             Yes
# 31             Yes
# 32             Yes
# 33             Yes
# 34             Yes
# 35             Yes
# 36             Yes
# 37             Yes
# 38             Yes
# 39             Yes
# 40             Yes
# 41             Yes
# 42             Yes
# 43             Yes
# 44             Yes
# 45             Yes
# 46             Yes
# 47             Yes
# 48             Yes
# 49             Yes

# %%
df.shape
# Out:
# (8760, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       8760 non-null   object
#  1   Rented Bike Count          8760 non-null   int64
#  2   Hour                       8760 non-null   int64
#  3   Temperature(°C)            8760 non-null   float64
#  4   Humidity(%)                8760 non-null   int64
#  5   Wind speed (m/s)           8760 non-null   float64
#  6   Visibility (10m)           8760 non-null   int64
#  7   Dew point temperature(°C)  8760 non-null   float64
#  8   Solar Radiation (MJ/m2)    8760 non-null   float64
#  9   Rainfall(mm)               8760 non-null   float64
#  10  Snowfall (cm)              8760 non-null   float64
#  11  Seasons                    8760 non-null   object
#  12  Holiday                    8760 non-null   object
#  13  Functioning Day            8760 non-null   object
# dtypes: float64(6), int64(4), object(4)
# memory usage: 958.2+ KB

# %%
df.describe(include = "all")
# Out:
#               Date  Rented Bike Count         Hour  Temperature(°C)  \
# count         8760        8760.000000  8760.000000      8760.000000
# unique         365                NaN          NaN              NaN
# top     01/12/2017                NaN          NaN              NaN
# freq            24                NaN          NaN              NaN
# mean           NaN         704.602055    11.500000        12.882922
# std            NaN         644.997468     6.922582        11.944825
# min            NaN           0.000000     0.000000       -17.800000
# 25%            NaN         191.000000     5.750000         3.500000
# 50%            NaN         504.500000    11.500000        13.700000
# 75%            NaN        1065.250000    17.250000        22.500000
# max            NaN        3556.000000    23.000000        39.400000
#
#         Humidity(%)  Wind speed (m/s)  Visibility (10m)  \
# count   8760.000000       8760.000000       8760.000000
# unique          NaN               NaN               NaN
# top             NaN               NaN               NaN
# freq            NaN               NaN               NaN
# mean      58.226256          1.724909       1436.825799
# std       20.362413          1.036300        608.298712
# min        0.000000          0.000000         27.000000
# 25%       42.000000          0.900000        940.000000
# 50%       57.000000          1.500000       1698.000000
# 75%       74.000000          2.300000       2000.000000
# max       98.000000          7.400000       2000.000000
#
#         Dew point temperature(°C)  Solar Radiation (MJ/m2)  Rainfall(mm)  \
# count                 8760.000000              8760.000000   8760.000000
# unique                        NaN                      NaN           NaN
# top                           NaN                      NaN           NaN
# freq                          NaN                      NaN           NaN
# mean                     4.073813                 0.569111      0.148687
# std                     13.060369                 0.868746      1.128193
# min                    -30.600000                 0.000000      0.000000
# 25%                     -4.700000                 0.000000      0.000000
# 50%                      5.100000                 0.010000      0.000000
# 75%                     14.800000                 0.930000      0.000000
# max                     27.200000                 3.520000     35.000000
#
#         Snowfall (cm) Seasons     Holiday Functioning Day
# count     8760.000000    8760        8760            8760
# unique            NaN       4           2               2
# top               NaN  Spring  No Holiday             Yes
# freq              NaN    2208        8328            8465
# mean         0.075068     NaN         NaN             NaN
# std          0.436746     NaN         NaN             NaN
# min          0.000000     NaN         NaN             NaN
# 25%          0.000000     NaN         NaN             NaN
# 50%          0.000000     NaN         NaN             NaN
# 75%          0.000000     NaN         NaN             NaN
# max          8.800000     NaN         NaN             NaN

# %%
# CHECKING NULL VALUES IN THE DATASET
df.isna().sum()
# Out:
# Date                         0
# Rented Bike Count            0
# Hour                         0
# Temperature(°C)              0
# Humidity(%)                  0
# Wind speed (m/s)             0
# Visibility (10m)             0
# Dew point temperature(°C)    0
# Solar Radiation (MJ/m2)      0
# Rainfall(mm)                 0
# Snowfall (cm)                0
# Seasons                      0
# Holiday                      0
# Functioning Day              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Rented Bike Count', 'Hour', 'Temperature(°C)', 'Humidity(%)',
#        'Wind speed (m/s)', 'Visibility (10m)', 'Dew point temperature(°C)',
#        'Solar Radiation (MJ/m2)', 'Rainfall(mm)', 'Snowfall (cm)', 'Seasons',
#        'Holiday', 'Functioning Day'],
#       dtype='object')

# %%
# RENAMING COLUMNS NAME
df.columns = ['date', 'rented_bike_count', 'hour', 'temperature', 'humidity',
       'wind_speed', 'visibility', 'dew_point_temperature',
       'solar_radiation', 'rainfall', 'snowfall', 'seasons',
       'holiday', 'functioning_day']

# %%
# CHANGING DATE COLUMN TO DATETIME DTYPE
df["date"] = pd.to_datetime(df['date'].astype(str), format='%d/%m/%Y')

# %%
# ADDING 3 NEW COLUMN AS DAY , MONTH , YEAR
df["day"] = df["date"].dt.day
df["month"] = df["date"].dt.month
df["year"] = df["date"].dt.year

# %%
# REMOVING DATE COLUMN FROM THE DATASET
df = df.iloc[:,1:]

# %%
df.columns
# Out:
# Index(['rented_bike_count', 'hour', 'temperature', 'humidity', 'wind_speed',
#        'visibility', 'dew_point_temperature', 'solar_radiation', 'rainfall',
#        'snowfall', 'seasons', 'holiday', 'functioning_day', 'day', 'month',
#        'year'],
#       dtype='object')

# %%
# SLECTING ALL CATEGORICAL COLUMNS
df_cat = df.select_dtypes(include= 'object')

# %%
# DEFINING FUNCTION FOR BAR PLOT OF COLUMNS
def plot_bar(nue):
  plt.figure(figsize=(8,5))
  sns.barplot(x = nue, y= 'rented_bike_count' , data = df, label="Some Label", palette= "husl")
  plt.show()

# %%
# CATEGORICAL BAR PLOT TOWARDS RENTED BIKE COUNT(TRAGET VARIABLE)
for i in df_cat.columns:
  plot_bar(i)

# %%
# NUMERICAL COLUMNS BAR PLOT TOWARDS RENTED BIKE COUNT(TRAGET VARIABLE)
for i in df.describe().columns[1:]:
  plot_bar(i)

# %% [markdown]
# We are provided one year's worth of data, which includes several meteorological variables such as seasons, humidity, and so on. We can see from the above data that a big number of bikes are hired when there is a working day/no holiday, and that this occurs more frequently throughout the summer season. Bikes are being hired more frequently during the working day, regardless of the season.

# %%
# CORELATION HEATMAP TO FIND OUT THE HIGHER CORELATING VARIABLES
plt.figure(figsize=(20,10))
sns.heatmap(df.corr().abs(),annot=True,cmap='Blues')
plt.show()

# %%
# DISTRIBUTION OF FEATURES
for i in df.describe().columns:
  plt.figure(figsize = (11,6))
  df[i].hist(bins = 50)
  plt.xlabel(i)
  plt.show()

# %% [markdown]
# **Hour**: There must be significant demand throughout office hours of 8 a.m. and 8 p.m., as well as early morning and late evening, which have distinctly different tendencies. Also, there is very little demand between the hours of 8 a.m. and 8 p.m.
#
# **Temperature**: Temperature has a negative link with biking needs in general. As a result, as the temperature rises, so does the number of bikes.
#
# **Humidity** is a hindrance to going on a bike ride. When the humidity rises, the number of bikes Demand falls.
#
# **Wind Speed**: There is a slight rise in the number of bikes due to wind speed, although the difference is minor.
#
# **Visibility**: When visibility is poor, people are less likely to ride bikes. When  visibility improves, the number of rental bikes count grows as well.

# %%
# BOXPLOT ON DATASET FOR SEEING THE OUTLIERS
plt.figure(figsize=(15, 8))
sns.boxplot(data = df)
plt.xticks(rotation = "vertical")
plt.show()

# %%
# PLOTING BOXPLOT TOWARDS RENTED BIKE COUNT(TRAGET VARIABLE)
for i in df.columns[1:]:
  plt.figure(figsize = (11,6))
  sns.boxplot(data = df,y = "rented_bike_count",x = i)
  plt.show()

# %%
df_cat.columns
# Out:
# Index(['seasons', 'holiday', 'functioning_day'], dtype='object')

# %%
def Functioning_Day(row):
  if str(row) == 'Yes':
    return 1
  else :
    return 0

# %%
df['functioning_day']=df.apply(lambda row : Functioning_Day(row['functioning_day']),axis=1)

df['functioning_day'].value_counts()a
# Out:
# 1    8465
# 0     295
# Name: functioning_day, dtype: int64

# %%
def Holiday_label(row):
  if str(row) == 'Holiday':
    return 1
  else :
    return 0

# %%
df['holiday']=df.apply(lambda row : Holiday_label(row['holiday']),axis=1)

df['holiday'].value_counts()
# Out:
# 0    8328
# 1     432
# Name: holiday, dtype: int64

# %%
def Seasons_label(row):
  if str(row) == 'Winter':
    return 0
  elif str(row) == 'Autumn':
    return 1
  elif str(row) == 'Spring':
    return 2
  elif  str(row) == 'Summer':
    return 3

# %%
df['seasons']=df.apply(lambda row : Seasons_label(row['seasons']),axis=1)

df['seasons'].value_counts()
# Out:
# 2    2208
# 3    2208
# 1    2184
# 0    2160
# Name: seasons, dtype: int64

# %%
df.head()
# Out:
#    rented_bike_count  hour  temperature  humidity  wind_speed  visibility  \
# 0                254     0         -5.2        37         2.2        2000
# 1                204     1         -5.5        38         0.8        2000
# 2                173     2         -6.0        39         1.0        2000
# 3                107     3         -6.2        40         0.9        2000
# 4                 78     4         -6.0        36         2.3        2000
#
#    dew_point_temperature  solar_radiation  rainfall  snowfall  seasons  \
# 0                  -17.6              0.0       0.0       0.0        0
# 1                  -17.6              0.0       0.0       0.0        0
# 2                  -17.7              0.0       0.0       0.0        0
# 3                  -17.6              0.0       0.0       0.0        0
# 4                  -18.6              0.0       0.0       0.0        0
#
#    holiday  functioning_day  day  month  year
# 0        0                1    1     12  2017
# 1        0                1    1     12  2017
# 2        0                1    1     12  2017
# 3        0                1    1     12  2017
# 4        0                1    1     12  2017

# %%
# INDEPENDENT VARIBLES
X = df.iloc[:,1:]

# %%
X.columns
# Out:
# Index(['hour', 'temperature', 'humidity', 'wind_speed', 'visibility',
#        'dew_point_temperature', 'solar_radiation', 'rainfall', 'snowfall',
#        'seasons', 'holiday', 'functioning_day', 'day', 'month', 'year'],
#       dtype='object')

# %%
# DEPENDED VARIBLE(TRAGET VARIBLE)
Y = df["rented_bike_count"]

# %%
# IMPORTING ML ALGORITHM FOR THE MODEL

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge


# SPLITTING THE X AND Y INTO X_TRAIN , X_TEST , Y_TRAIN , Y_TEST
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 5)

# %% [markdown]
# LINEAR REGRESSION

# %%
# TRAINING THE MODEl
reg = LinearRegression()
reg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# INTERCEPT AND COFFIENT 
reg.intercept_ , reg.coef_
# Out:
# (-636945.7027740447,
#  array([ 2.73721172e+01,  1.61583180e+01, -1.09421987e+01,  2.07254879e+01,
#         -3.76995564e-03,  1.02444603e+01, -7.42923751e+01, -5.78284849e+01,
#          2.11814216e+01,  2.72467160e+01, -1.14704979e+02,  8.62931317e+02,
#         -1.33856637e+00,  3.19615348e+01,  3.15516416e+02]))

# %%
# PREDICTING X_TEST
y_pred=reg.predict(X_test)

# %%
# IMPOERTING SKLEARN METRICS FOR EVALUTING THE MODDEL SCORES
from sklearn.metrics import r2_score,mean_squared_error

# %%
# R-SQUARED
r2_score(Y_test, y_pred)
# Out:
# 0.5482402293597666

# %%
# MODEL FITIING ON TEST DATASET
reg.score(X_test, Y_test)
# Out:
# 0.5482402293597666

# %%
# MODEL FITTING ON TRAIN DATASET
reg.score(X_train, Y_train)
# Out:
# 0.5359005556894705

# %%
# ADJUSTED R-SQURED , MEAN SQUARED ERROR, ROOT MEAN SQUARED ERROR
print("Adjusted R2 : ",1-(1-r2_score((Y_test), (y_pred)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
MSE  = mean_squared_error(Y_test, y_pred)
print("MSE :" , MSE)
RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)
# Out:
# Adjusted R2 :  0.5451232116230584
# MSE : 184857.33595218146
# RMSE : 429.95038778001054

# %%
# PLOTTING FIRST 50 Y_TEST AND Y_PRED
plt.figure(figsize=(15,10))
plt.plot(np.array(Y_test[:50]), color = "orange")
plt.plot(y_pred[:50], color = "red")
plt.title("LinearRegression")
plt.legend(["Predicted","Actual"])
plt.show()

# %% [markdown]
# LASSO REGRESSION

# %%
# IMPORTING ML ALGORITHM FOR THE MODEL AND GRIDSEARCH CV
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso

# %%
# PERFORMING HYPERPARAMETER TUNNING AND FITTING THE TRAIN DATASET 
rf_grid = GridSearchCV(Lasso(),
                       param_grid = {"alpha" : [1.1,0.001]},
                       cv = 5, verbose=2, scoring='roc_auc')

rf_grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV] END ..........................................alpha=1.1; total time=   0.1s
# [CV] END ..........................................alpha=1.1; total time=   0.1s
# [CV] END ..........................................alpha=1.1; total time=   0.1s
# [CV] END ..........................................alpha=1.1; total time=   0.1s
# [CV] END ..........................................alpha=1.1; total time=   0.1s
# [CV] END ........................................alpha=0.001; total time=   0.1s
# [CV] END ........................................alpha=0.001; total time=   0.1s
# [CV] END ........................................alpha=0.001; total time=   0.1s
# [CV] END ........................................alpha=0.001; total time=   0.1s
# [CV] END ........................................alpha=0.001; total time=   0.1s
# GridSearchCV(cv=5, estimator=Lasso(), param_grid={'alpha': [1.1, 0.001]},
#              scoring='roc_auc', verbose=2)

# %%
# BEST HYPERPARAMETER
rf_grid.best_params_
# Out:
# {'alpha': 1.1}

# %%
# FITTING THE MODEL WITH BEST HYPERPARAMETER
lasso = Lasso(alpha=1.1)
lasso.fit(X_train, Y_train)
# Out:
# Lasso(alpha=1.1)

# %%
# COFFICENT
lasso.coef_
# Out:
# array([ 2.74163131e+01,  1.65830603e+01, -1.07582147e+01,  1.82937669e+01,
#        -4.00227116e-04,  1.01513878e+01, -7.08621027e+01, -5.68735886e+01,
#         1.29334235e+01,  2.58712869e+01, -9.49975269e+01,  8.22197247e+02,
#        -1.18922567e+00,  2.96384818e+01,  2.79632666e+02])

# %%
# INTERCEPT
lasso.intercept_
# Out:
# -564500.5287939652

# %%
# PRECDICTING X_TEST
y_pred = lasso.predict(X_test)

# %%
# R_SQUARED
r2_score (Y_test, y_pred)
# Out:
# 0.5472906744050867

# %%
#  MODEL FITIING ON TEST DATASET
lasso.score(X_test, Y_test)
# Out:
# 0.5472906744050867

# %%
# MODEL FITIING ON TRAIN DATASET
lasso.score(X_train, Y_train)
# Out:
# 0.5355979395613004

# %%
# ADJUSTED R-SQURED , MEAN SQUARED ERROR, ROOT MEAN SQUARED ERROR
print("Adjusted R2 : ",1-(1-r2_score((Y_test), (y_pred)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
MSE  = mean_squared_error(Y_test, y_pred)
print("MSE :" , MSE)
RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)
# Out:
# Adjusted R2 :  0.544167105001258
# MSE : 185245.88803377468
# RMSE : 430.402007469499

# %%
# PLOTTING FIRST 50 Y_TEST AND Y_PRED
plt.figure(figsize=(15,10))
plt.plot(np.array(Y_test[:50]), color = "orange")
plt.plot(y_pred[:50], color = "red")
plt.title("Lasso")
plt.legend(["Predicted","Actual"])
plt.show()

# %% [markdown]
# RIDG REGRESSION

# %%
# PERFORMING HYPERPARAMETER TUNNING AND FITTING THE TRAIN DATASET 
rf_grid = GridSearchCV(Ridge(),
                       param_grid = {"alpha" : [0,0.0000000001]},
                       cv = 5, verbose=2, scoring='roc_auc')

rf_grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV] END ............................................alpha=0; total time=   0.0s
# [CV] END ............................................alpha=0; total time=   0.0s
# [CV] END ............................................alpha=0; total time=   0.0s
# [CV] END ............................................alpha=0; total time=   0.0s
# [CV] END ............................................alpha=0; total time=   0.0s
# [CV] END ........................................alpha=1e-10; total time=   0.0s
# [CV] END ........................................alpha=1e-10; total time=   0.0s
# [CV] END ........................................alpha=1e-10; total time=   0.0s
# [CV] END ........................................alpha=1e-10; total time=   0.0s
# [CV] END ........................................alpha=1e-10; total time=   0.0s
# GridSearchCV(cv=5, estimator=Ridge(), param_grid={'alpha': [0, 1e-10]},
#              scoring='roc_auc', verbose=2)

# %%
# BEST HYPERPARAMETER
rf_grid.best_params_
# Out:
# {'alpha': 0}

# %%
# FITTING THE MODEL WITH BEST HYPERPARAMETER
ridge = Ridge(alpha=0)
ridge.fit(X_train,Y_train)
# Out:
# Ridge(alpha=0)

# %%
# PREDICTING X_TEST
y_pred = ridge.predict(X_test)

# %%
# COFFIENT
ridge.coef_
# Out:
# array([ 2.73721172e+01,  1.61583180e+01, -1.09421987e+01,  2.07254879e+01,
#        -3.76995564e-03,  1.02444603e+01, -7.42923751e+01, -5.78284849e+01,
#         2.11814216e+01,  2.72467160e+01, -1.14704979e+02,  8.62931317e+02,
#        -1.33856637e+00,  3.19615348e+01,  3.15516416e+02])

# %%
# INTERCEPT
ridge.intercept_
# Out:
# -636945.7027740534

# %%
#  MODEL FITIING ON TEST DATASET
ridge.score(X_test, Y_test)
# Out:
# 0.5482402293597651

# %%
#  MODEL FITIING ON TRAIN DATASET
ridge.score(X_train, Y_train)
# Out:
# 0.5359005556894713

# %%
# R_SQUARED
r2_score(Y_test, y_pred )
# Out:
# 0.5482402293597651

# %%
# ADJUSTED R-SQURED , MEAN SQUARED ERROR, ROOT MEAN SQUARED ERROR
print("Adjusted R2 : ",1-(1-r2_score((Y_test), (y_pred)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
MSE  = mean_squared_error(Y_test, y_pred)
print("MSE :" , MSE)
RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)
# Out:
# Adjusted R2 :  0.545123211623057
# MSE : 184857.33595218207
# RMSE : 429.9503877800113

# %%
# PLOTTING FIRST 50 Y_TEST AND Y_PRED
plt.figure(figsize=(15,10))
plt.plot(np.array(Y_test[:50]), color = "orange")
plt.plot(y_pred[:50], color = "red")
plt.title("Ridge")
plt.legend(["Predicted","Actual"])
plt.show()

# %% [markdown]
# ELASTIC NET

# %%
# IMPORTING ELASTIC NET
from sklearn.linear_model import ElasticNet

# %%
# PERFORMING HYPERPARAMETER TUNNING AND FITTING THE TRAIN DATASET 
rf_grid = GridSearchCV(ElasticNet(),
                       param_grid = {"alpha" : [0,1] , 'l1_ratio' : [0.99, 0.999]},
                       cv = 5, verbose=2, scoring='roc_auc')

rf_grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV] END .............................alpha=0, l1_ratio=0.99; total time=   0.1s
# [CV] END .............................alpha=0, l1_ratio=0.99; total time=   0.1s
# [CV] END .............................alpha=0, l1_ratio=0.99; total time=   0.1s
# [CV] END .............................alpha=0, l1_ratio=0.99; total time=   0.1s
# [CV] END .............................alpha=0, l1_ratio=0.99; total time=   0.1s
# [CV] END ............................alpha=0, l1_ratio=0.999; total time=   0.1s
# [CV] END ............................alpha=0, l1_ratio=0.999; total time=   0.1s
# [CV] END ............................alpha=0, l1_ratio=0.999; total time=   0.1s
# [CV] END ............................alpha=0, l1_ratio=0.999; total time=   0.2s
# [CV] END ............................alpha=0, l1_ratio=0.999; total time=   0.1s
# [CV] END .............................alpha=1, l1_ratio=0.99; total time=   0.1s
# [CV] END .............................alpha=1, l1_ratio=0.99; total time=   0.1s
# [CV] END .............................alpha=1, l1_ratio=0.99; total time=   0.1s
# [CV] END .............................alpha=1, l1_ratio=0.99; total time=   0.1s
# [CV] END .............................alpha=1, l1_ratio=0.99; total time=   0.1s
# [CV] END ............................alpha=1, l1_ratio=0.999; total time=   0.1s
# [CV] END ............................alpha=1, l1_ratio=0.999; total time=   0.1s
# [CV] END ............................alpha=1, l1_ratio=0.999; total time=   0.1s
# [CV] END ............................alpha=1, l1_ratio=0.999; total time=   0.1s
# [CV] END ............................alpha=1, l1_ratio=0.999; total time=   0.1s
# GridSearchCV(cv=5, estimator=ElasticNet(),
#              param_grid={'alpha': [0, 1], 'l1_ratio': [0.99, 0.999]},
#              scoring='roc_auc', verbose=2)

# %%
# BEST HYPER PARAMETER
rf_grid.best_params_
# Out:
# {'alpha': 0, 'l1_ratio': 0.99}

# %%
# USING BEST HYPER PARAMENTER OM THE MODEL
eln = ElasticNet(alpha= 0, l1_ratio= 0.99)

# %%
# FITTING TRAIN DATA SET TO THE MODEL
eln.fit(X_train, Y_train)
# Out:
# ElasticNet(alpha=0, l1_ratio=0.99)

# %%
# PREDICTING X_TEST
y_pred = eln.predict(X_test)

# %%
# R_SQUARED
r2_score(Y_test, y_pred)
# Out:
# 0.5482403392219246

# %%
#  MODEL FITIING ON TEST DATASET
eln.score(X_test, Y_test)
# Out:
# 0.5482403392219246

# %%
#  MODEL FITIING ON TRAIN DATASET
eln.score(X_train, Y_train)
# Out:
# 0.5359005556850355

# %%
# ADJUSTED R-SQURED , MEAN SQUARED ERROR, ROOT MEAN SQUARED ERROR
print("Adjusted R2 : ",1-(1-r2_score((Y_test), (y_pred)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
MSE  = mean_squared_error(Y_test, y_pred)
print("MSE :" , MSE)
RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)
# Out:
# Adjusted R2 :  0.545123322243235
# MSE : 184857.29099725813
# RMSE : 429.9503355008089

# %%
# PLOTTING FIRST 50 Y_TEST AND Y_PRED
plt.figure(figsize=(15,10))
plt.plot(np.array(Y_test[:50]), color = "orange")
plt.plot(y_pred[:50], color = "red")
plt.title("ElasticNet")
plt.legend(["Predicted","Actual"])
plt.show()

# %% [markdown]
# DESION TREE

# %%
# IMPOERTING DESISION TREE REGRESSOR
from sklearn.tree import DecisionTreeRegressor

# %%
# PERFORMING HYPERPARAMETER TUNNING AND FITTING THE TRAIN DATASET 
rf_grid = GridSearchCV(DecisionTreeRegressor(),
                       param_grid = {'max_depth' :[ i for i in range(8,11)], 'min_samples_split' :[ i for i in range(8,11)], 'min_samples_leaf': [i for i in range(6,11)]},
                       cv = 5, verbose=2, scoring='roc_auc')

rf_grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 45 candidates, totalling 225 fits
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=9; total time=   0.1s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=9; total time=   0.1s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=9, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=6, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=7, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=8, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=9, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=8; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=9; total time=   0.1s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=9; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [8, 9, 10],
#                          'min_samples_leaf': [6, 7, 8, 9, 10],
#                          'min_samples_split': [8, 9, 10]},
#              scoring='roc_auc', verbose=2)

# %%
# BEST HYPER PARAMETER
rf_grid.best_params_
# Out:
# {'max_depth': 8, 'min_samples_leaf': 6, 'min_samples_split': 8}

# %%
# USING BEST HYPER PARAMENTER OM THE MODEL
t = DecisionTreeRegressor(max_depth = 8, min_samples_split = 8, min_samples_leaf = 6)

# %%
#  MODEL FITIING ON TRAIN DATASET
t.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(max_depth=8, min_samples_leaf=6, min_samples_split=8)

# %%
# PREDICTING X_TEST
y_pred = t.predict(X_test)

# %%
# R_SQUARED
r2_score(Y_test, y_pred)
# Out:
# 0.803387160956738

# %%
#  MODEL FITIING ON TEST DATASET
t.score(X_test, Y_test)
# Out:
# 0.803387160956738

# %%
#  MODEL FITIING ON TRAIN DATASET
t.score(X_train, Y_train)
# Out:
# 0.837350919172177

# %%
# ADJUSTED R-SQURED , MEAN SQUARED ERROR, ROOT MEAN SQUARED ERROR
print("Adjusted R2 : ",1-(1-r2_score((Y_test), (y_pred)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
MSE  = mean_squared_error(Y_test, y_pred)
print("MSE :" , MSE)
RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)
# Out:
# Adjusted R2 :  0.8020305866303126
# MSE : 80452.7715870404
# RMSE : 283.6419778295173

# %%
# PLOTTING FIRST 50 Y_TEST AND Y_PRED
plt.figure(figsize=(15,10))
plt.plot(np.array(Y_test[:50]), color = "orange")
plt.plot(y_pred[:50], color = "red")
plt.title("DecisionTreeRegressor")
plt.legend(["Predicted","Actual"])
plt.show()

# %% [markdown]
# RandomForest

# %%
# IMPORTING RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
# PERFORMING HYPERPARAMETER TUNNING AND FITTING THE TRAIN DATASET 
rf_grid = GridSearchCV( RandomForestRegressor(),
                       param_grid = {'max_depth' : [18,19,20], 'min_samples_split' : [7,8,9], 'min_samples_leaf' : [7,6,8]},
                       cv = 5, verbose=2, scoring='roc_auc')

rf_grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=7; total time=   2.2s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=7; total time=   2.0s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=8; total time=   2.4s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=8; total time=   2.3s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=8; total time=   2.2s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=8; total time=   2.3s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=8; total time=   2.4s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=9; total time=   2.4s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=9; total time=   2.1s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=7, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=8; total time=   2.4s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=18, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=7, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=8; total time=   2.2s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=19, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=7, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=7; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=8; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=6, min_samples_split=9; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=7; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=8; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=8, min_samples_split=9; total time=   1.6s
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [18, 19, 20],
#                          'min_samples_leaf': [7, 6, 8],
#                          'min_samples_split': [7, 8, 9]},
#              scoring='roc_auc', verbose=2)

# %%
# BEST HYPER PARAMETER
rf_grid.best_params_
# Out:
# {'alpha': 0, 'l1_ratio': 0.99}

# %%
# USING BEST HYPER PARAMENTER OM THE MODEL
rfr = RandomForestRegressor(max_depth = 18, min_samples_split = 7, min_samples_leaf = 7)

# %%
#  MODEL FITIING ON TRAIN DATASET
rfr.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(max_depth=18, min_samples_leaf=7, min_samples_split=7)

# %%
# PREDICTING X_TEST
y_pred = rfr.predict(X_test)

# %%
#  MODEL FITIING ON TRAIN DATASET
rfr.score(X_train, Y_train)
# Out:
# 0.9267123768746647

# %%
# #  MODEL FITIING ON TEST DATASET
rfr.score(X_test, Y_test)
# Out:
# 0.872580426254778

# %%
# R_SQUARED
r2_score(Y_test , y_pred)
# Out:
# 0.872580426254778

# %%
# ADJUSTED R-SQURED , MEAN SQUARED ERROR, ROOT MEAN SQUARED ERROR
print("Adjusted R2 : ",1-(1-r2_score((Y_test), (y_pred)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
MSE  = mean_squared_error(Y_test, y_pred)
print("MSE :" , MSE)
RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)
# Out:
# Adjusted R2 :  0.8717012663623317
# MSE : 52139.31049531687
# RMSE : 228.3403391766704

# %%
# PLOTTING FIRST 50 Y_TEST AND Y_PRED
plt.figure(figsize=(15,10))
plt.plot(np.array(Y_test[:50]), color = "orange")
plt.plot(y_pred[:50], color = "red")
plt.title("RandomForestRegressor")
plt.legend(["Predicted","Actual"])
plt.show()

# %% [markdown]
# ADA BOOSTING

# %%
# IMPORTING AdaBoostRegressor
from sklearn.ensemble import AdaBoostRegressor

# %%
# PERFORMING HYPERPARAMETER TUNNING
rf_grid = GridSearchCV( AdaBoostRegressor(),
                       param_grid = { 'n_estimators' :[50, 60], 'learning_rate' : [1.0,0.75], 'loss' :['linear', 'square' , 'exponential'], "random_state" : [0,1,2]}, cv=3
                       , verbose=2, scoring='roc_auc')

# %%
# FITTING THE TRAIN DATASET 
rf_grid.fit(X_train,Y_train)
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [CV] END learning_rate=1.0, loss=linear, n_estimators=50, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=50, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=50, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=50, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=50, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=50, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=linear, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=square, n_estimators=50, random_state=0; total time=   0.3s
# [CV] END learning_rate=1.0, loss=square, n_estimators=50, random_state=0; total time=   0.3s
# [CV] END learning_rate=1.0, loss=square, n_estimators=50, random_state=0; total time=   0.3s
# [CV] END learning_rate=1.0, loss=square, n_estimators=50, random_state=1; total time=   0.3s
# [CV] END learning_rate=1.0, loss=square, n_estimators=50, random_state=1; total time=   0.3s
# [CV] END learning_rate=1.0, loss=square, n_estimators=50, random_state=1; total time=   0.3s
# [CV] END learning_rate=1.0, loss=square, n_estimators=50, random_state=2; total time=   0.3s
# [CV] END learning_rate=1.0, loss=square, n_estimators=50, random_state=2; total time=   0.3s
# [CV] END learning_rate=1.0, loss=square, n_estimators=50, random_state=2; total time=   0.3s
# [CV] END learning_rate=1.0, loss=square, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=square, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=square, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=square, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=square, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=square, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=square, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=square, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=square, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=50, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=50, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=50, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=50, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=50, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=50, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=1.0, loss=exponential, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=50, random_state=0; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=50, random_state=0; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=50, random_state=0; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=50, random_state=1; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=50, random_state=1; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=50, random_state=1; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=linear, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=square, n_estimators=50, random_state=0; total time=   0.3s
# [CV] END learning_rate=0.75, loss=square, n_estimators=50, random_state=0; total time=   0.3s
# [CV] END learning_rate=0.75, loss=square, n_estimators=50, random_state=0; total time=   0.3s
# [CV] END learning_rate=0.75, loss=square, n_estimators=50, random_state=1; total time=   0.3s
# [CV] END learning_rate=0.75, loss=square, n_estimators=50, random_state=1; total time=   0.3s
# [CV] END learning_rate=0.75, loss=square, n_estimators=50, random_state=1; total time=   0.3s
# [CV] END learning_rate=0.75, loss=square, n_estimators=50, random_state=2; total time=   0.3s
# [CV] END learning_rate=0.75, loss=square, n_estimators=50, random_state=2; total time=   0.3s
# [CV] END learning_rate=0.75, loss=square, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=square, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=0.75, loss=square, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=0.75, loss=square, n_estimators=60, random_state=0; total time=   0.4s
# [CV] END learning_rate=0.75, loss=square, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=0.75, loss=square, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=0.75, loss=square, n_estimators=60, random_state=1; total time=   0.4s
# [CV] END learning_rate=0.75, loss=square, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=square, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=square, n_estimators=60, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=50, random_state=0; total time=   0.4s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=50, random_state=0; total time=   0.4s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=50, random_state=0; total time=   0.4s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=50, random_state=1; total time=   0.4s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=50, random_state=1; total time=   0.4s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=50, random_state=1; total time=   0.4s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=50, random_state=2; total time=   0.4s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=60, random_state=0; total time=   0.5s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=60, random_state=0; total time=   0.5s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=60, random_state=0; total time=   0.5s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=60, random_state=1; total time=   0.5s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=60, random_state=1; total time=   0.5s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=60, random_state=1; total time=   0.5s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=60, random_state=2; total time=   0.5s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=60, random_state=2; total time=   0.5s
# [CV] END learning_rate=0.75, loss=exponential, n_estimators=60, random_state=2; total time=   0.5s
# GridSearchCV(cv=3, estimator=AdaBoostRegressor(),
#              param_grid={'learning_rate': [1.0, 0.75],
#                          'loss': ['linear', 'square', 'exponential'],
#                          'n_estimators': [50, 60], 'random_state': [0, 1, 2]},
#              scoring='roc_auc', verbose=2)

# %%
# BEST HYPER PARAMETER
rf_grid.best_params_
# Out:
# {'learning_rate': 1.0, 'loss': 'linear', 'n_estimators': 50, 'random_state': 0}

# %%
# USING BEST HYPER PARAMENTER OM THE MODEL
adr = AdaBoostRegressor(n_estimators=50, learning_rate=0.1, loss='linear', random_state= 0)

# %%
#  MODEL FITIING ON TRAIN DATASET
adr.fit(X_train, Y_train)
# Out:
# AdaBoostRegressor(learning_rate=0.1, random_state=0)

# %%
# PREDICTING X_TEST
y_pred = adr.predict(X_test)

# %%
#  MODEL FITIING ON TRAIn DATASET
adr.score(X_train, Y_train)
# Out:
# 0.6473818235766907

# %%
#  MODEL FITIING ON TEST DATASET
adr.score(X_test, Y_test)
# Out:
# 0.6397724930383073

# %%
# R_SQUARED
r2_score(Y_test, y_pred)
# Out:
# 0.6397724930383073

# %%
# ADJUSTED R-SQURED , MEAN SQUARED ERROR, ROOT MEAN SQUARED ERROR
print("Adjusted R2 : ",1-(1-r2_score((Y_test), (y_pred)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
MSE  = mean_squared_error(Y_test, y_pred)
print("MSE :" , MSE)
RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)
# Out:
# Adjusted R2 :  0.6372870226590868
# MSE : 147402.8933104472
# RMSE : 383.93084443744186

# %%
# PLOTTING FIRST 50 Y_TEST AND Y_PRED
plt.figure(figsize=(15,10))
plt.plot(np.array(Y_test[:50]), color = "orange")
plt.plot(y_pred[:50], color = "red")
plt.title("AdaBoostRegressor")
plt.legend(["Predicted","Actual"])
plt.show()

# %% [markdown]
# GradientBoostingRegressor

# %%
# IMPORTING GradientBoostingRegressor

from sklearn.ensemble import GradientBoostingRegressor

# %%
# PERFORMING HYPERPARAMETER TUNNING AND FITTING THE TRAIN DATASET 
rf_grid = GridSearchCV( GradientBoostingRegressor(),
                       param_grid ={
    "learning_rate": [0.001, 0.1],
    "min_samples_split": [5,2,6],
    "min_samples_leaf": [5,6,7],
    "max_depth":[8,9,10],
    "n_estimators":[50]
    }, cv=5
                       , verbose=2, scoring='roc_auc')
rf_grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=8, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=9, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.9s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=10, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=8, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=9, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=5, min_samples_split=5, n_estimators=50; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=6, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=6, min_samples_split=2, n_estimators=50; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=6, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=7, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=7, min_samples_split=2, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=7, min_samples_split=6, n_estimators=50; total time=   1.3s
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.001, 0.1], 'max_depth': [8, 9, 10],
#                          'min_samples_leaf': [5, 6, 7],
#                          'min_samples_split': [5, 2, 6], 'n_estimators': [50]},
#              scoring='roc_auc', verbose=2)

# %%
# BEST HYPER PARAMETER
rf_grid.best_params_
# Out:
# {'learning_rate': 0.001,
#  'max_depth': 8,
#  'min_samples_leaf': 5,
#  'min_samples_split': 5,
#  'n_estimators': 50}

# %%
# USING BEST HYPER PARAMENTER OM THE MODEL
gbr = GradientBoostingRegressor(criterion = 'friedman_mse',
  learning_rate = 0.1,
  max_depth = 25,
  max_features = 'auto',
  min_samples_leaf = 20,
  min_samples_split = 10,
  n_estimators = 50)

# %%
#  MODEL FITIING ON TRAIN DATASET
gbr.fit(X_train, Y_train)
# Out:
# GradientBoostingRegressor(max_depth=25, max_features='auto',
#                           min_samples_leaf=20, min_samples_split=10,
#                           n_estimators=50)

# %%
# PREDICTING X_TEST
y_pred = gbr.predict(X_test)

# %%
# R_SQUARED
r2_score(Y_test, y_pred)
# Out:
# 0.8931878406095475

# %%
#  MODEL FITIING ON TRAIN DATASET
gbr.score(X_train, Y_train)
# Out:
# 0.08264741521725438

# %%
#  MODEL FITIING ON TEST DATASET
gbr.score(X_test, Y_test)
# Out:
# 0.8931878406095475

# %%
# ADJUSTED R-SQURED , MEAN SQUARED ERROR, ROOT MEAN SQUARED ERROR
print("Adjusted R2 : ",1-(1-r2_score((Y_test), (y_pred)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
MSE  = mean_squared_error(Y_test, y_pred)
print("MSE :" , MSE)
RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)
# Out:
# Adjusted R2 :  0.8924508661887302
# MSE : 43706.88254121484
# RMSE : 209.06191078533374

# %%
# PLOTTING FIRST 50 Y_TEST AND Y_PRED
plt.figure(figsize=(15,10))
plt.plot(np.array(Y_test[:50]), color = "orange")
plt.plot(y_pred[:50], color = "red")
plt.title("GradientBoostingRegressor")
plt.legend(["Predicted","Actual"])
plt.show()

# %% [markdown]
# XGB

# %%
# IMPORTING XGBRegressor
from xgboost import XGBRegressor

# %%
# PERFORMING HYPERPARAMETER TUNNING AND FITTING THE TRAIN DATASET 
rf_grid = GridSearchCV(XGBRegressor(random_state=0),
                       param_grid = {"min_child_weight":[10,20], 
            'eta': [0.004,0.04,40], 
            'colsample_bytree':[0.7], 
            'max_depth': [7,9,11],
          
          }, cv=3 , verbose=1)
rf_grid.fit(X_train,Y_train)
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [10:26:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:26:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:27:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:27:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:27:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:27:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:27:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:27:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# GridSearchCV(cv=3, estimator=XGBRegressor(),
#              param_grid={'colsample_bytree': [0.7], 'eta': [0.004, 0.04, 40],
#                          'max_depth': [7, 9, 11],
#                          'min_child_weight': [10, 20]},
#              verbose=1)

# %%
rf_grid.best_estimator_.get_params()
# Out:
# {'base_score': 0.5,
#  'booster': 'gbtree',
#  'colsample_bylevel': 1,
#  'colsample_bynode': 1,
#  'colsample_bytree': 0.7,
#  'eta': 0.004,
#  'gamma': 0,
#  'importance_type': 'gain',
#  'learning_rate': 0.1,
#  'max_delta_step': 0,
#  'max_depth': 11,
#  'min_child_weight': 20,
#  'missing': None,
#  'n_estimators': 100,
#  'n_jobs': 1,
#  'nthread': None,
#  'objective': 'reg:linear',
#  'random_state': 0,
#  'reg_alpha': 0,
#  'reg_lambda': 1,
#  'scale_pos_weight': 1,
#  'seed': None,
#  'silent': None,
#  'subsample': 1,
#  'verbosity': 1}

# %%
reg_optimal_model = rf_grid.best_estimator_

# %%
train_preds = reg_optimal_model.predict(X_train)
test_preds = reg_optimal_model.predict(X_test)

# %%
reg_optimal_model.score(X_test,Y_test)
# Out:
# 0.890838409803174

# %%
# BEST HYPER PARAMETER
rf_grid.best_params_
# Out:
# {'colsample_bytree': 0.7,
#  'eta': 0.004,
#  'max_depth': 11,
#  'min_child_weight': 20}

# %%
# USING BEST HYPER PARAMENTER OM THE MODEL
xbr = XGBRegressor(colsample_bytree = 0.7, eta = 0.004, max_depth = 9, min_child_weight = 10)

# %%
#  MODEL FITIING ON TRAIN DATASET
xbr.fit(X_train, Y_train)
# Out:
# [10:30:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(colsample_bytree=0.7, eta=0.004, max_depth=9, min_child_weight=10)

# %%
# PREDICTING X_TEST
y_pred = xbr.predict(X_test)

# %%
# R_SQUARED
r2_score(Y_test, y_pred)
# Out:
# 0.889114101998751

# %%
#  MODEL FITIING ON TRAIN DATASET
xbr.score(X_train, Y_train)
# Out:
# 0.9759743429387965

# %%
#  MODEL FITIING ON TEST DATASET
xbr.score(X_test, Y_test)
# Out:
# 0.889114101998751

# %%
# ADJUSTED R-SQURED , MEAN SQUARED ERROR, ROOT MEAN SQUARED ERROR
print("Adjusted R2 : ",1-(1-r2_score((Y_test), (y_pred)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
MSE  = mean_squared_error(Y_test, y_pred)
print("MSE :" , MSE)
RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)
# Out:
# Adjusted R2 :  0.888349019905826
# MSE : 45373.83147270149
# RMSE : 213.01134118328415

# %%
# PLOTTING FIRST 50 Y_TEST AND Y_PRED
plt.figure(figsize=(15,10))
plt.plot(np.array(Y_test[:52]), color = "orange")
plt.plot(y_pred[:52], color = "red")
plt.title("XGBRegressor")
plt.legend(["Predicted","Actual"])
plt.show()

# %% [markdown]
# ### **Observations**
#
#
# *  The major factor affecting the Rental bikes demand are Temperature, Visibility, Rainfall and Snowfall. The rentals are independent of the wind speed and the humidity, because they are almost constant over the months.
# *   The rental bike is in most demand in the morning from 7 AM to 9 AM and in the evening from 5 PM to 8 PM. Hence, the Rental Bike companies need better planning for the availability of the rental bikes for this time period the most.
# *   The Rental Booking happens the most in summers specifically from May to July. Hence, the rental companies needs to plan the staffings required for the maintenance of bikes and smooth running of the business for this period the most.
# *   The Rental Bike demand is showing increasing trend. Hence, it is a booming business and there is a great scope of expansion.
# *   Linear regression, Lasso regression, Ridge regression, Decision Tree, Random Forest, AdaBoost, Gradient Boosting, Extreme Gradient Boosting Regressor, and XG Boost are just a few of the machine learning models we've employed. The accuracy of the Gradient Boosting Regressor and XG Boost is 89.2 percent and 89.1 percent, respectively.
# Hence, gradient boosting was used because it produces the most accurate results.

# %% [markdown]
# ### **Conclusion**
# We have used many ML models such as Linear regression, Lasso Regression, Ridge Regression, Elastic Net, Decision Tree, Random Forest, ADABoost, Gradient Boosting, Extreme Gradient Boosting Regressor and XG Boost. The Gradient Boosting Regressor and XG Boost are giving good accuracy with the accuracy being 89.2% and 89.1%.
# We have chosen Gradient boosting as Gradient Boosting is giving the most accurate results.
#
# As we can see the total amount of bike rentals increases with the temperature per month. Whereas it seems that the rentals are independent of the wind speed and the humidity, because they are almost constant over the months. This also confirms on the one hand the high correlation between rentals and temperature and on the other hand that nice weather could be a good predictor. So people mainly rent bikes on nice days and nice temperature. This could be important of planning new bike rental stations.
